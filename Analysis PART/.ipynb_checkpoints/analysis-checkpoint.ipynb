# %%
import pandas as pd

# %%
ipl = pd.read_csv(r'ipl-matches.csv')

# %%
ipl.head(1)
# Out:
#         ID       City        Date Season MatchNumber             Team1  \
# 0  1312200  Ahmedabad  2022-05-29   2022       Final  Rajasthan Royals
#
#             Team2                             Venue        TossWinner  \
# 0  Gujarat Titans  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals
#
#   TossDecision SuperOver     WinningTeam    WonBy  Margin method  \
# 0          bat         N  Gujarat Titans  Wickets     7.0    NaN
#
#   Player_of_Match                                       Team1Players  \
# 0       HH Pandya  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
#
#                                         Team2Players      Umpire1      Umpire2
# 0  ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...  CB Gaffaney  Nitin Menon

# %% [markdown]
# ## API-1 All Teams name

# %%
teams = list(set(list(ipl['Team1']) + list(ipl['Team2'])))
teams
# Out:
# ['Pune Warriors',
#  'Royal Challengers Bangalore',
#  'Lucknow Super Giants',
#  'Punjab Kings',
#  'Gujarat Lions',
#  'Delhi Capitals',
#  'Kolkata Knight Riders',
#  'Delhi Daredevils',
#  'Kochi Tuskers Kerala',
#  'Rising Pune Supergiants',
#  'Chennai Super Kings',
#  'Gujarat Titans',
#  'Rising Pune Supergiant',
#  'Deccan Chargers',
#  'Kings XI Punjab',
#  'Mumbai Indians',
#  'Rajasthan Royals',
#  'Sunrisers Hyderabad']

# %% [markdown]
# ## API-2 Team vs Team

# %%
team1 = 'Kolkata Knight Riders'
team2 = 'Royal Challengers Bangalore'

# %%
df1 = ipl[((ipl.Team1 == team1) & (ipl.Team2 == team2)) | ((ipl.Team1 == team2) & (ipl.Team2 == team1))]

# %%
df1
# Out:
#           ID       City        Date   Season MatchNumber  \
# 68   1304052     Mumbai  2022-03-30     2022           6
# 76   1254115    Sharjah  2021-10-11     2021  Eliminator
# 103  1254087  Abu Dhabi  2021-09-20     2021          31
# 124  1254067    Chennai  2021-04-18     2021          10
# 155  1216494  Abu Dhabi  2020-10-21  2020/21          39
# 166  1216540        NaN  2020-10-12  2020/21          28
# 219  1178410    Kolkata  2019-04-19     2019          35
# 237  1175372  Bengaluru  2019-04-05     2019          17
# 286  1136589  Bengaluru  2018-04-29     2018          29
# 312  1136563    Kolkata  2018-04-08     2018           3
# 327  1082636  Bangalore  2017-05-07     2017          46
# 346  1082617    Kolkata  2017-04-23     2017          27
# 385   980995    Kolkata  2016-05-16     2016          48
# 403   980959  Bangalore  2016-05-02     2016          30
# 459   829771  Bangalore  2015-05-02     2015          33
# 487   829713    Kolkata  2015-04-11     2015           5
# 502   734027    Kolkata  2014-05-22     2014          49
# 541   729299        NaN  2014-04-24     2014          11
# 568   598057     Ranchi  2013-05-12     2013          60
# 616   598008  Bangalore  2013-04-11     2013          12
# 666   548344    Kolkata  2012-04-28     2012          38
# 692   548315  Bangalore  2012-04-10     2012          10
# 717   501255  Bangalore  2011-05-14     2011          58
# 751   501222    Kolkata  2011-04-22     2011          24
# 792   419148  Bangalore  2010-04-10  2009/10          43
# 830   419109    Kolkata  2010-03-14  2009/10           4
# 853   392221  Centurion  2009-05-12     2009          41
# 875   392199     Durban  2009-04-29     2009          19
# 922   336010    Kolkata  2008-05-08  2007/08          29
# 949   335982  Bangalore  2008-04-18  2007/08           1
#
#                            Team1                        Team2  \
# 68         Kolkata Knight Riders  Royal Challengers Bangalore
# 76   Royal Challengers Bangalore        Kolkata Knight Riders
# 103  Royal Challengers Bangalore        Kolkata Knight Riders
# 124  Royal Challengers Bangalore        Kolkata Knight Riders
# 155        Kolkata Knight Riders  Royal Challengers Bangalore
# 166  Royal Challengers Bangalore        Kolkata Knight Riders
# 219  Royal Challengers Bangalore        Kolkata Knight Riders
# 237  Royal Challengers Bangalore        Kolkata Knight Riders
# 286  Royal Challengers Bangalore        Kolkata Knight Riders
# 312  Royal Challengers Bangalore        Kolkata Knight Riders
# 327  Royal Challengers Bangalore        Kolkata Knight Riders
# 346        Kolkata Knight Riders  Royal Challengers Bangalore
# 385        Kolkata Knight Riders  Royal Challengers Bangalore
# 403  Royal Challengers Bangalore        Kolkata Knight Riders
# 459  Royal Challengers Bangalore        Kolkata Knight Riders
# 487        Kolkata Knight Riders  Royal Challengers Bangalore
# 502        Kolkata Knight Riders  Royal Challengers Bangalore
# 541  Royal Challengers Bangalore        Kolkata Knight Riders
# 568        Kolkata Knight Riders  Royal Challengers Bangalore
# 616  Royal Challengers Bangalore        Kolkata Knight Riders
# 666        Kolkata Knight Riders  Royal Challengers Bangalore
# 692  Royal Challengers Bangalore        Kolkata Knight Riders
# 717  Royal Challengers Bangalore        Kolkata Knight Riders
# 751        Kolkata Knight Riders  Royal Challengers Bangalore
# 792  Royal Challengers Bangalore        Kolkata Knight Riders
# 830        Kolkata Knight Riders  Royal Challengers Bangalore
# 853  Royal Challengers Bangalore        Kolkata Knight Riders
# 875  Royal Challengers Bangalore        Kolkata Knight Riders
# 922        Kolkata Knight Riders  Royal Challengers Bangalore
# 949  Royal Challengers Bangalore        Kolkata Knight Riders
#
#                                         Venue                   TossWinner  \
# 68         Dr DY Patil Sports Academy, Mumbai  Royal Challengers Bangalore
# 76                    Sharjah Cricket Stadium  Royal Challengers Bangalore
# 103          Zayed Cricket Stadium, Abu Dhabi  Royal Challengers Bangalore
# 124  MA Chidambaram Stadium, Chepauk, Chennai  Royal Challengers Bangalore
# 155                      Sheikh Zayed Stadium        Kolkata Knight Riders
# 166                   Sharjah Cricket Stadium  Royal Challengers Bangalore
# 219                              Eden Gardens        Kolkata Knight Riders
# 237                     M.Chinnaswamy Stadium        Kolkata Knight Riders
# 286                     M.Chinnaswamy Stadium        Kolkata Knight Riders
# 312                              Eden Gardens        Kolkata Knight Riders
# 327                     M Chinnaswamy Stadium        Kolkata Knight Riders
# 346                              Eden Gardens  Royal Challengers Bangalore
# 385                              Eden Gardens  Royal Challengers Bangalore
# 403                     M Chinnaswamy Stadium        Kolkata Knight Riders
# 459                     M Chinnaswamy Stadium  Royal Challengers Bangalore
# 487                              Eden Gardens  Royal Challengers Bangalore
# 502                              Eden Gardens  Royal Challengers Bangalore
# 541                   Sharjah Cricket Stadium  Royal Challengers Bangalore
# 568        JSCA International Stadium Complex        Kolkata Knight Riders
# 616                     M Chinnaswamy Stadium  Royal Challengers Bangalore
# 666                              Eden Gardens        Kolkata Knight Riders
# 692                     M Chinnaswamy Stadium  Royal Challengers Bangalore
# 717                     M Chinnaswamy Stadium  Royal Challengers Bangalore
# 751                              Eden Gardens  Royal Challengers Bangalore
# 792                     M Chinnaswamy Stadium  Royal Challengers Bangalore
# 830                              Eden Gardens        Kolkata Knight Riders
# 853                           SuperSport Park  Royal Challengers Bangalore
# 875                                 Kingsmead        Kolkata Knight Riders
# 922                              Eden Gardens        Kolkata Knight Riders
# 949                     M Chinnaswamy Stadium  Royal Challengers Bangalore
#
#     TossDecision SuperOver                  WinningTeam    WonBy  Margin  \
# 68         field         N  Royal Challengers Bangalore  Wickets     3.0
# 76           bat         N        Kolkata Knight Riders  Wickets     4.0
# 103          bat         N        Kolkata Knight Riders  Wickets     9.0
# 124          bat         N  Royal Challengers Bangalore     Runs    38.0
# 155          bat         N  Royal Challengers Bangalore  Wickets     8.0
# 166          bat         N  Royal Challengers Bangalore     Runs    82.0
# 219        field         N  Royal Challengers Bangalore     Runs    10.0
# 237        field         N        Kolkata Knight Riders  Wickets     5.0
# 286        field         N        Kolkata Knight Riders  Wickets     6.0
# 312        field         N        Kolkata Knight Riders  Wickets     4.0
# 327        field         N        Kolkata Knight Riders  Wickets     6.0
# 346        field         N        Kolkata Knight Riders     Runs    82.0
# 385        field         N  Royal Challengers Bangalore  Wickets     9.0
# 403        field         N        Kolkata Knight Riders  Wickets     5.0
# 459        field         N  Royal Challengers Bangalore  Wickets     7.0
# 487        field         N  Royal Challengers Bangalore  Wickets     3.0
# 502        field         N        Kolkata Knight Riders     Runs    30.0
# 541        field         N        Kolkata Knight Riders     Runs     2.0
# 568        field         N        Kolkata Knight Riders  Wickets     5.0
# 616        field         N  Royal Challengers Bangalore  Wickets     8.0
# 666          bat         N        Kolkata Knight Riders     Runs    47.0
# 692        field         N        Kolkata Knight Riders     Runs    42.0
# 717        field         N  Royal Challengers Bangalore  Wickets     4.0
# 751        field         N  Royal Challengers Bangalore  Wickets     9.0
# 792        field         N  Royal Challengers Bangalore  Wickets     7.0
# 830        field         N        Kolkata Knight Riders  Wickets     7.0
# 853        field         N  Royal Challengers Bangalore  Wickets     6.0
# 875          bat         N  Royal Challengers Bangalore  Wickets     5.0
# 922          bat         N        Kolkata Knight Riders     Runs     5.0
# 949        field         N        Kolkata Knight Riders     Runs   140.0
#
#     method  Player_of_Match  \
# 68     NaN     PWH de Silva
# 76     NaN        SP Narine
# 103    NaN         CV Varun
# 124    NaN   AB de Villiers
# 155    NaN   Mohammed Siraj
# 166    NaN   AB de Villiers
# 219    NaN          V Kohli
# 237    NaN       AD Russell
# 286    NaN          CA Lynn
# 312    NaN        SP Narine
# 327    NaN        SP Narine
# 346    NaN  NM Coulter-Nile
# 385    NaN          V Kohli
# 403    NaN       AD Russell
# 459    NaN    Mandeep Singh
# 487    NaN         CH Gayle
# 502    NaN       RV Uthappa
# 541    NaN          CA Lynn
# 568    NaN        JH Kallis
# 616    NaN         CH Gayle
# 666    NaN        G Gambhir
# 692    NaN         L Balaji
# 717    D/L         CH Gayle
# 751    NaN         CH Gayle
# 792    NaN    R Vinay Kumar
# 830    NaN        MK Tiwary
# 853    NaN      LRPL Taylor
# 875    NaN       MV Boucher
# 922    NaN       SC Ganguly
# 949    NaN      BB McCullum
#
#                                           Team1Players  \
# 68   ['AM Rahane', 'VR Iyer', 'SS Iyer', 'N Rana', ...
# 76   ['D Padikkal', 'V Kohli', 'KS Bharat', 'GJ Max...
# 103  ['V Kohli', 'D Padikkal', 'KS Bharat', 'GJ Max...
# 124  ['V Kohli', 'D Padikkal', 'RM Patidar', 'GJ Ma...
# 155  ['Shubman Gill', 'RA Tripathi', 'N Rana', 'T B...
# 166  ['AJ Finch', 'D Padikkal', 'V Kohli', 'AB de V...
# 219  ['PA Patel', 'V Kohli', 'AD Nath', 'MM Ali', '...
# 237  ['PA Patel', 'V Kohli', 'AB de Villiers', 'MP ...
# 286  ['Q de Kock', 'BB McCullum', 'V Kohli', 'M Voh...
# 312  ['BB McCullum', 'Q de Kock', 'V Kohli', 'AB de...
# 327  ['CH Gayle', 'Mandeep Singh', 'V Kohli', 'AB d...
# 346  ['SP Narine', 'G Gambhir', 'RV Uthappa', 'MK P...
# 385  ['RV Uthappa', 'G Gambhir', 'MK Pandey', 'YK P...
# 403  ['KL Rahul', 'CH Gayle', 'V Kohli', 'AB de Vil...
# 459  ['CH Gayle', 'V Kohli', 'AB de Villiers', 'Man...
# 487  ['RV Uthappa', 'G Gambhir', 'MK Pandey', 'SA Y...
# 502  ['RV Uthappa', 'G Gambhir', 'MK Pandey', 'YK P...
# 541  ['PA Patel', 'YV Takawale', 'V Kohli', 'Yuvraj...
# 568  ['MS Bisla', 'G Gambhir', 'JH Kallis', 'YK Pat...
# 616  ['CH Gayle', 'MA Agarwal', 'V Kohli', 'AB de V...
# 666  ['BB McCullum', 'G Gambhir', 'JH Kallis', 'YK ...
# 692  ['CA Pujara', 'CH Gayle', 'V Kohli', 'AB de Vi...
# 717  ['CH Gayle', 'LA Pomersbach', 'V Kohli', 'AB d...
# 751  ['JH Kallis', 'BJ Haddin', 'G Gambhir', 'YK Pa...
# 792  ['S Sriram', 'JH Kallis', 'R Dravid', 'RV Utha...
# 830  ['BJ Hodge', 'MK Tiwary', 'SC Ganguly', 'CA Pu...
# 853  ['JD Ryder', 'JH Kallis', 'RV Uthappa', 'LRPL ...
# 875  ['JH Kallis', 'SP Goswami', 'KP Pietersen', 'V...
# 922  ['A Chopra', 'BJ Hodge', 'SC Ganguly', 'DJ Hus...
# 949  ['R Dravid', 'W Jaffer', 'V Kohli', 'JH Kallis...
#
#                                           Team2Players          Umpire1  \
# 68   ['F du Plessis', 'Anuj Rawat', 'V Kohli', 'DJ ...    J Madanagopal
# 76   ['Shubman Gill', 'VR Iyer', 'RA Tripathi', 'N ...      CB Gaffaney
# 103  ['Shubman Gill', 'VR Iyer', 'AD Russell', 'N R...      CB Gaffaney
# 124  ['N Rana', 'Shubman Gill', 'RA Tripathi', 'EJG...    C Shamshuddin
# 155  ['D Padikkal', 'AJ Finch', 'Gurkeerat Singh', ...        VK Sharma
# 166  ['T Banton', 'Shubman Gill', 'N Rana', 'EJG Mo...   RK Illingworth
# 219  ['CA Lynn', 'SP Narine', 'Shubman Gill', 'RV U...         IJ Gould
# 237  ['CA Lynn', 'SP Narine', 'RV Uthappa', 'N Rana...     AK Chaudhary
# 286  ['CA Lynn', 'SP Narine', 'RV Uthappa', 'N Rana...     AK Chaudhary
# 312  ['SP Narine', 'CA Lynn', 'RV Uthappa', 'N Rana...       A Deshmukh
# 327  ['CA Lynn', 'SP Narine', 'C de Grandhomme', 'G...      AY Dandekar
# 346  ['CH Gayle', 'V Kohli', 'Mandeep Singh', 'AB d...      CB Gaffaney
# 385  ['CH Gayle', 'V Kohli', 'AB de Villiers', 'SR ...      CB Gaffaney
# 403  ['RV Uthappa', 'G Gambhir', 'CA Lynn', 'MK Pan...        M Erasmus
# 459  ['RV Uthappa', 'G Gambhir', 'AD Russell', 'RN ...        JD Cloete
# 487  ['CH Gayle', 'V Kohli', 'KD Karthik', 'Mandeep...           S Ravi
# 502  ['CH Gayle', 'YV Takawale', 'V Kohli', 'Yuvraj...     AK Chaudhary
# 541  ['JH Kallis', 'G Gambhir', 'MK Pandey', 'CA Ly...        Aleem Dar
# 568  ['CA Pujara', 'CH Gayle', 'V Kohli', 'AB de Vi...         NJ Llong
# 616  ['MS Bisla', 'G Gambhir', 'JH Kallis', 'YK Pat...        Asad Rauf
# 666  ['TM Dilshan', 'CH Gayle', 'V Kohli', 'AB de V...        Asad Rauf
# 692  ['JH Kallis', 'G Gambhir', 'MS Bisla', 'YK Pat...           S Ravi
# 717  ['JH Kallis', 'EJG Morgan', 'G Gambhir', 'MK T...      RE Koertzen
# 751  ['TM Dilshan', 'CH Gayle', 'V Kohli', 'AB de V...        SS Hazare
# 792  ['SC Ganguly', 'CH Gayle', 'BB McCullum', 'MK ...      K Hariharan
# 830  ['JH Kallis', 'SP Goswami', 'MK Pandey', 'V Ko...  HDPK Dharmasena
# 853  ['BB McCullum', 'SC Ganguly', 'AN Ghosh', 'DJ ...        M Erasmus
# 875  ['BB McCullum', 'CH Gayle', 'BJ Hodge', 'SC Ga...        MR Benson
# 922  ['J Arunkumar', 'S Chanderpaul', 'MV Boucher',...        Asad Rauf
# 949  ['SC Ganguly', 'BB McCullum', 'RT Ponting', 'D...        Asad Rauf
#
#             Umpire2
# 68    Navdeep Singh
# 76        VK Sharma
# 103          S Ravi
# 124     Nitin Menon
# 155          S Ravi
# 166    K Srinivasan
# 219     Nitin Menon
# 237     CB Gaffaney
# 286        NJ Llong
# 312   C Shamshuddin
# 327   C Shamshuddin
# 346       CK Nandan
# 385  A Nand Kishore
# 403          S Ravi
# 459       PG Pathak
# 487   C Shamshuddin
# 502       CK Nandan
# 541     VA Kulkarni
# 568       K Srinath
# 616    AK Chaudhary
# 666     BR Doctrove
# 692       RJ Tucker
# 717       RB Tiffin
# 751       RB Tiffin
# 792       DJ Harper
# 830       AM Saheba
# 853       SS Hazare
# 875  TH Wijewardene
# 922       IL Howell
# 949     RE Koertzen

# %%
tmp = df1.shape[0]
tmp
# Out:
# 30

# %%
mwt1 = df1[df1.WinningTeam == team1].shape[0]
mwt1
# Out:
# 16

# %%
mwt2 = df1[df1.WinningTeam == team2].shape[0]
mwt2
# Out:
# 14

# %%
draws = tmp - (mwt1 + mwt2)
draws
# Out:
# 0

# %%
def teamVsTeam(team1, team2):
    df1 = ipl[((ipl.Team1 == team1) & (ipl.Team2 == team2)) | ((ipl.Team1 == team2) & (ipl.Team2 == team1))]
    tmp = df1.shape[0]
    mwt1 = df1[df1.WinningTeam == team1].shape[0]
    mwt2 = df1[df1.WinningTeam == team2].shape[0]
    draws = tmp - (mwt1 + mwt2)
    
    team_vs_team_record = {
        'Total matches played': tmp,
        'Matches won by ' + team1: mwt1,
        'Matches won by ' + team2: mwt2,
        'Draws': draws
    }
    return team_vs_team_record

# %%
teamVsTeam(team1, team2)
# Out:
# {'Total matches played': 30,
#  'Matches won by Kolkata Knight Riders': 16,
#  'Matches won by Royal Challengers Bangalore': 14,
#  'Draws': 0}

# %% [markdown]
# ## API-3 Team record

# %%
ipl.head(1)
# Out:
#         ID       City        Date Season MatchNumber             Team1  \
# 0  1312200  Ahmedabad  2022-05-29   2022       Final  Rajasthan Royals
#
#             Team2                             Venue        TossWinner  \
# 0  Gujarat Titans  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals
#
#   TossDecision SuperOver     WinningTeam    WonBy  Margin method  \
# 0          bat         N  Gujarat Titans  Wickets     7.0    NaN
#
#   Player_of_Match                                       Team1Players  \
# 0       HH Pandya  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
#
#                                         Team2Players      Umpire1      Umpire2
# 0  ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...  CB Gaffaney  Nitin Menon

# %%
team = 'Chennai Super Kings'

# %%
df2 = ipl[(ipl.Team1 == team) | (ipl.Team2 == team)]
tmp = df2.shape[0]
tmp
# Out:
# 208

# %%
mw = df2[df2.WinningTeam == team].shape[0]
mw
# Out:
# 121

# %%
draws = df2[df2.WinningTeam.isnull()].shape[0]
draws
# Out:
# 0

# %%
ml = tmp - (mw + draws)
ml
# Out:
# 87

# %%
sw = (df2[df2.MatchNumber == 'Final'].WinningTeam == team).sum()
sw
# Out:
# 4

# %%
df2[df2.MatchNumber == 'Final'].WinningTeam == team
# Out:
# 74      True
# 194    False
# 254     True
# 433    False
# 552    False
# 628    False
# 702     True
# 775     True
# 892    False
# Name: WinningTeam, dtype: bool

# %%
def teamRecord(team):
    df2 = ipl[(ipl.Team1 == team) | (ipl.Team2 == team)]
    tmp = df2.shape[0]
    mw = df2[df2.WinningTeam == team].shape[0]
    draws = df2[df2.WinningTeam.isnull()].shape[0]
    ml = tmp - (mw + draws)
    sw = (df2[df2.MatchNumber == 'Final'].WinningTeam == team).sum()
    
    overall = {
        'Total matches played': tmp,
        'Match won': mw,
        'Match lost': ml,
        'Draws': draws,
        'Season winner': '{} in {}'.format(sw, sw_list)
    }

    return overall
